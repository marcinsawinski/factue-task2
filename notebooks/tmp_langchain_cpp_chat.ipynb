# %%
import os

os.chdir("/mnt/openfact/users/msawinski/factue-task2")
from factue.methods.llm_langchain.llm import Llm

import json

# %%
chat_model = Llm(
    model_name="llama3.1:8b",  # type: ignore
    provider="ollama",  # type: ignore
    mode="chat",  # type: ignore
    temperature="0.0",  # type: ignore
)

# %%
promt_format = """\nOutput ONLY JSON: in the format {{"rating": 0-10, "reason": "reason for rating","alternative": "formulate new one sentence claim that better represents the text of post}}."""

prmpt_system = """You are an expert journalist. Your task is to validate if a claim was accuratley extracted from a post. Compare it and determine how accurately the claim reflects post. You outout rating from 0 to 10, where 0 means the claim is completely different from original text and 10 means the claim most accurately reflects the post. If claim does not accurately reflect the post then generate alternative claim. Do not include additional information. Compare ONLY the claim text with post text. Do not infere information that is not directly included in post. Keep original wording when possible.Focus on the most important infrmation. The claim should be concise and reflect ONLY most important information from the post. Preserve names and named entities from the post."""


claim = """Photo shows Louis Armstrong as a child"""
post = """The Karnofsky Jewish family, who immigrated to the United States from Lithuania, employed a 7-year-old boy and adopted (so to speak) him into their home.  He was originally given homework to get food because he was a starving kid.  He remained under the Jewish families employ, until he was 12  Karnofsky gave him money to buy his first instrument, which was a common instrument in Jewish families.  They really admired his musical talent.Later, when he became a professional"""
prmpt_user = """POST:\n{post}\n\nCLAIM:\n{claim}"""

from langchain.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", prmpt_system + promt_format),
        ("human", prmpt_user),
    ]
)
prompt = prompt_template.invoke({"post": post, "claim": claim})
reposonse = chat_model.invoke(prompt).content
print(reposonse)
# Out:
# {
# "rating": 0,
# "reason": "The claim does not mention the Karnofsky family or their relationship with the boy, and only mentions Louis Armstrong's photo",
# "alternative": "A young Jewish boy from Lithuania was employed by the Karnofsky family in the US"
# }

# %%
claim = """Photo shows Louis Armstrong as a child"""
while claim and len(claim) > 0:
    prompt = prompt_template.invoke({"post": post, "claim": claim})
    reposonse = chat_model.invoke(prompt).content

    try:
        response = json.loads(reposonse)
        rating = response["rating"]
        reason = response["reason"]
        alternative = response["alternative"]
        pp(str(rating) + claim + "|||" + reason)
    except:
        print("Error in response")
        print(reposonse)
        claim = None
    if claim != alternative and len(alternative) > 10 and alternative:
        claim = alternative
# Out:
# ('0A young Jewish boy from Lithuania was employed by the Karnofsky family in '
#  'the US|||The claim does not mention the Karnofsky family or their '
#  "relationship with the boy, and only mentions Louis Armstrong's photo")
# ('8A young Jewish boy from Lithuania was employed and adopted by the Karnofsky '
#  'family in the US.|||The claim accurately states that a young Jewish boy from '
#  'Lithuania was employed by the Karnofsky family in the US, but it does not '
#  'mention his age or the circumstances of his employment.')
# ('8A young Jewish boy from Lithuania was employed by and adopted into the '
#  "Karnofsky family in the US.|||The claim accurately reflects the post's main "
#  'information about the Karnofsky family employing and adopting a young Jewish '
#  'boy from Lithuania, but it does not mention the age of the boy or his '
#  'musical talent.')
# ('8A 7-year-old Jewish boy from Lithuania was employed by and eventually '
#  'adopted into the Karnofsky family in the US.|||The claim accurately reflects '
#  "the post's main information about the Karnofsky family employing and "
#  'adopting a young Jewish boy, but it simplifies some details.')
# ('8A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and eventually received support to develop his musical '
#  "talent.|||The claim accurately reflects the post's information about the "
#  'Karnofsky family employing and adopting a young boy, but it simplifies some '
#  'details.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical talent.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ('9A 7-year-old Jewish boy from Lithuania was employed by the Karnofsky family '
#  'in the US and received financial support to develop his musical '
#  "talents.|||The claim accurately reflects the post's main points, including "
#  'the age of the boy, his employment by the Karnofsky family, and their '
#  'support for his musical development.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 8
#       2 while claim and len(claim) > 0:
#       3     prompt = prompt_template.invoke(
#       4     {
#       5         "post": post,
#       6         "claim": claim
#       7     })
# ----> 8     reposonse = chat_model.invoke(prompt).content
#      10     try:
#      11         response = json.loads(reposonse)
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:369, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     357 @override
#     358 def invoke(
#     359     self,
#    (...)    364     **kwargs: Any,
#     365 ) -> BaseMessage:
#     366     config = ensure_config(config)
#     367     return cast(
#     368         "ChatGeneration",
# --> 369         self.generate_prompt(
#     370             [self._convert_input(input)],
#     371             stop=stop,
#     372             callbacks=config.get("callbacks"),
#     373             tags=config.get("tags"),
#     374             metadata=config.get("metadata"),
#     375             run_name=config.get("run_name"),
#     376             run_id=config.pop("run_id", None),
#     377             **kwargs,
#     378         ).generations[0][0],
#     379     ).message
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:946, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     937 @override
#     938 def generate_prompt(
#     939     self,
#    (...)    943     **kwargs: Any,
#     944 ) -> LLMResult:
#     945     prompt_messages = [p.to_messages() for p in prompts]
# --> 946     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:765, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     762 for i, m in enumerate(input_messages):
#     763     try:
#     764         results.append(
# --> 765             self._generate_with_cache(
#     766                 m,
#     767                 stop=stop,
#     768                 run_manager=run_managers[i] if run_managers else None,
#     769                 **kwargs,
#     770             )
#     771         )
#     772     except BaseException as e:
#     773         if run_managers:
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1009     result = generate_from_stream(iter(chunks))
#    1010 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1011     result = self._generate(
#    1012         messages, stop=stop, run_manager=run_manager, **kwargs
#    1013     )
#    1014 else:
#    1015     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_ollama/chat_models.py:715, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     708 def _generate(
#     709     self,
#     710     messages: list[BaseMessage],
#    (...)    713     **kwargs: Any,
#     714 ) -> ChatResult:
# --> 715     final_chunk = self._chat_stream_with_aggregation(
#     716         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     717     )
#     718     generation_info = final_chunk.generation_info
#     719     chat_generation = ChatGeneration(
#     720         message=AIMessage(
#     721             content=final_chunk.text,
#    (...)    726         generation_info=generation_info,
#     727     )
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_ollama/chat_models.py:652, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     643 def _chat_stream_with_aggregation(
#     644     self,
#     645     messages: list[BaseMessage],
#    (...)    649     **kwargs: Any,
#     650 ) -> ChatGenerationChunk:
#     651     final_chunk = None
# --> 652     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     653         if final_chunk is None:
#     654             final_chunk = chunk
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_ollama/chat_models.py:737, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     730 def _iterate_over_stream(
#     731     self,
#     732     messages: list[BaseMessage],
#     733     stop: Optional[list[str]] = None,
#     734     **kwargs: Any,
#     735 ) -> Iterator[ChatGenerationChunk]:
#     736     is_thinking = False
# --> 737     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     738         if not isinstance(stream_resp, str):
#     739             if stream_resp.get("done") is True:
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/langchain_ollama/chat_models.py:639, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     636 chat_params = self._chat_params(messages, stop, **kwargs)
#     638 if chat_params["stream"]:
# --> 639     yield from self._client.chat(**chat_params)
#     640 else:
#     641     yield self._client.chat(**chat_params)
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/ollama/_client.py:170, in Client._request.<locals>.inner()
#     167   e.response.read()
#     168   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 170 for line in r.iter_lines():
#     171   part = json.loads(line)
#     172   if err := part.get('error'):
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpx/_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpx/_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/notebooks/env_py311_ms_factue/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
