# %%
wd = '/Users/marcinsawinski/Documents/GitHub/factue-task2'
import sys, os
os.chdir(wd)

# %% [markdown]
# # alt splits

# %%
# import pandas as pd
# alt_splits = pd.read_parquet('/Users/marcinsawinski/Documents/GitHub/factue-task2/data/raw/persuasion/alt_splits.parquet')
# alt_splits

# %% [markdown]
# # Trail

# %%
from pathlib import Path
import pandas as pd
from factue.utils.vars import PROJECT_ROOT
import numpy as np

base_dir = PROJECT_ROOT / "data/raw/persuasion/trial_data/TRIAL-ANNOTATED"
langs = ["PL", "RU", "BG", "SI"]

records = []

for lang in langs:
    lang_path = base_dir / lang
    raw_docs_path = lang_path / "raw-documents"
    subtask1_path = lang_path / "subtask-1-annotations.txt"
    subtask2_path = lang_path / "subtask-2-annotations.txt"

    # Load all raw documents
    raw_docs = {
        f.name: f.read_text(encoding="utf-8") for f in raw_docs_path.glob("*.txt")
    }

    # Load subtask-2 annotations into a dict
    subtask2_map = {}
    if subtask2_path.exists():
        with subtask2_path.open(encoding="utf-8") as f:
            for line in f:
                parts = line.strip().split("\t")
                if len(parts) >= 4:
                    fname, start, end, *labels = parts
                    key = (fname, int(start), int(end))
                    subtask2_map[key] = labels

    # Parse subtask-1 annotations and extract spans
    with subtask1_path.open(encoding="utf-8") as f:
        for line in f:
            parts = line.strip().split("\t")
            if len(parts) != 4:
                continue
            fname, start, end, label_bin = parts
            start, end = int(start), int(end)
            text = raw_docs.get(fname, "")[start:end]
            labels_multi = subtask2_map.get((fname, start, end), [])

            records.append(
                {
                    "filename": fname,
                    "start": start,
                    "end": end,
                    "text_lang": lang,
                    "text": text,
                    "label_bin": label_bin.lower() == "true",
                    "label_multi": labels_multi,
                }
            )

# Create a DataFrame
trial = pd.DataFrame(records)
trial['base_split'] = 'trial'

# %% [markdown]
# # Train

# %%
from pathlib import Path
import pandas as pd
from collections import defaultdict
from factue.utils.vars import PROJECT_ROOT

base_dir = PROJECT_ROOT / "data/raw/persuasion/train_data"
langs = ["PL", "RU", "BG", "SI"]

records = []

for lang in langs:
    lang_path = base_dir / lang
    raw_docs_path = lang_path / "raw-documents"
    subtask1_path = lang_path / "subtask-1-annotations.txt"
    subtask2_path = lang_path / "subtask-2-annotations.txt"
    subtask2_subspans_path = lang_path / "subtask-2-spans-annotations.txt"

    # Load all raw documents
    raw_docs = {
        f.name: f.read_text(encoding="utf-8") for f in raw_docs_path.glob("*.txt")
    }

    # Load subtask-2 annotations into a dict
    subtask2_map = {}
    if subtask2_path.exists():
        with subtask2_path.open(encoding="utf-8") as f:
            for line in f:
                parts = line.strip().split("\t")
                if len(parts) >= 4:
                    fname, start, end, *labels = parts
                    key = (fname, int(start), int(end))
                    subtask2_map[key] = labels

    # Load subspans
    subspan_data = defaultdict(list)
    if subtask2_subspans_path.exists():
        with subtask2_subspans_path.open(encoding="utf-8") as f:
            for line in f:
                parts = line.strip().split("\t")
                if len(parts) == 5:
                    fname, sub_start, sub_end, label, text = parts
                    subspan_data[fname].append({
                        "start": int(sub_start),
                        "end": int(sub_end),
                        "label": label,
                        "text": text
                    })

    # Parse subtask-1 annotations and extract spans
    with subtask1_path.open(encoding="utf-8") as f:
        for line in f:
            parts = line.strip().split("\t")
            if len(parts) != 4:
                continue
            fname, start, end, label_bin = parts
            start, end = int(start), int(end)
            text = raw_docs.get(fname, "")[start:end]
            labels_multi = subtask2_map.get((fname, start, end), [])

            # Match subspans
            subspans_within = defaultdict(list)
            for sub in subspan_data.get(fname, []):
                if start <= sub["start"] and sub["end"] <= end:
                    subspans_within[sub["label"]].append(sub["text"])

            records.append({
                "filename": fname,
                "start": start,
                "end": end,
                "text_lang": lang,
                "text": text,
                "label_bin": label_bin.lower() == "true",
                "label_multi": labels_multi,
                **subspans_within  # this spreads the subspan labels as keys with list of texts as values
            })

# Create a DataFrame
train = pd.DataFrame(records)
train['base_split'] = 'train'

# %%
train
# Out:
#                                   filename  start   end text_lang  \
# 0    pl_current_affairs_09_01_2025_n03.txt      0    87        PL
# 1    pl_current_affairs_09_01_2025_n03.txt     89   261        PL
# 2    pl_current_affairs_09_01_2025_n03.txt    263   872        PL
# 3    pl_current_affairs_09_01_2025_n03.txt    874  1322        PL
# 4    pl_current_affairs_09_01_2025_n03.txt   1324  1465        PL
# ..                                     ...    ...   ...       ...
# 994        SI_interpelation_interior_7.txt      0   274        SI
# 995        SI_interpelation_interior_7.txt    276   837        SI
# 996        SI_interpelation_interior_7.txt    839  2596        SI
# 997        SI_interpelation_interior_7.txt   2598  5288        SI
# 998        SI_interpelation_interior_7.txt   5290  9806        SI
#
#                                                   text  label_bin  \
# 0    Wicemarszałek Włodzimierz Czarzasty:\nDziękuję...      False
# 1    Poseł Anna Gembicka:\nBardzo dziękuję.\nPanie ...       True
# 2    (Poseł Władysław Dajczak: Ha, ha, ha! To prawd...       True
# 3    Kolejne pytanie. Na stronie Wód Polskich pojaw...       True
# 4    Jeszcze tylko jedna rzecz. Nawet politycy Lewi...       True
# ..                                                 ...        ...
# 994  Zanimivo ob tem dejstvu je, da se pa na jugovz...       True
# 995  Prav tako poročila obeh policijskih postaj gov...       True
# 996  Naslednji primer: žena pomočnika generalnega d...       True
# 997  Policisti prav tako dobijo navodila, naj ne sp...       True
# 998  In dodatki za nadomeščanje vodje. Netransparen...       True
#
#                                            label_multi  \
# 0                                                   []
# 1    [Questioning_the_Reputation, Name_Calling-Labe...
# 2    [Conversation_Killer, Appeal_to_Hypocrisy, Loa...
# 3                                         [Repetition]
# 4                               [Appeal_to_Popularity]
# ..                                                 ...
# 994  [Causal_Oversimplification, Appeal_to_Fear-Pre...
# 995             [Appeal_to_Values, Red_Herring, Doubt]
# 996  [Causal_Oversimplification, Exaggeration-Minim...
# 997  [Consequential_Oversimplification, Exaggeratio...
# 998  [False_Equivalence, Exaggeration-Minimisation,...
#
#                             Questioning_the_Reputation  \
# 0                                                  NaN
# 1    [Przypomnę pani kilka faktów, bo widzę, że fak...
# 2             [Oczywiście to jest wasza stara śpiewka]
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996  [mora po navodilu pomočnika generalnega direkt...
# 997  [Taka navodila policistom seveda preprečujejo ...
# 998  [Posel dobi podjetje iz hobotnice slovenskih m...
#
#         Name_Calling-Labeling  \
# 0                         NaN
# 1                   [zielona]
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 994                       NaN
# 995                       NaN
# 996              [golobistov]
# 997                       NaN
# 998  [golobistov, golobistov]
#
#                                    Appeal_to_Hypocrisy  ... Straw_Man Slogans  \
# 0                                                  NaN  ...       NaN     NaN
# 1                                                  NaN  ...       NaN     NaN
# 2    [został uchwalony program wieloletni, który pr...  ...       NaN     NaN
# 3                                                  NaN  ...       NaN     NaN
# 4                                                  NaN  ...       NaN     NaN
# ..                                                 ...  ...       ...     ...
# 994                                                NaN  ...       NaN     NaN
# 995                                                NaN  ...       NaN     NaN
# 996  [žena pomočnika generalnega direktorja policij...  ...       NaN     NaN
# 997  [Čeprav je z nepravilnostmi večkrat seznanila ...  ...       NaN     NaN
# 998  [Netransparentno in neupravičeno se uporabljaj...  ...       NaN     NaN
#
#                               Appeal_to_Fear-Prejudice  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994         [problematike kot so Romi in pa migracije]
# 995                                                NaN
# 996  [zato se prične znatno povečevati število ileg...
# 997  [V času bivanja v Sloveniji, se nekateri ilega...
# 998                                                NaN
#
#                              Causal_Oversimplification  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994  [za rešitev te problematike, torej povečanega ...
# 995                                                NaN
# 996  [S tem se ilegalnim migrantom sporoči, da je p...
# 997                                                NaN
# 998                                                NaN
#
#          Appeal_to_Authority False_Dilemma-No_Choice Whataboutism  \
# 0                        NaN                     NaN          NaN
# 1                        NaN                     NaN          NaN
# 2                        NaN                     NaN          NaN
# 3                        NaN                     NaN          NaN
# 4                        NaN                     NaN          NaN
# ..                       ...                     ...          ...
# 994                      NaN                     NaN          NaN
# 995                      NaN                     NaN          NaN
# 996                      NaN                     NaN          NaN
# 997  [tožilka Mateja Gončin]                     NaN          NaN
# 998  [po mnenju poznavalcev]                     NaN          NaN
#
#                                      False_Equivalence Guilt_by_Association  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 994                                                NaN                  NaN
# 995                                                NaN                  NaN
# 996                                                NaN                  NaN
# 997                                                NaN                  NaN
# 998  [Če primerjamo torej ceno mobilne hiške, ki jo...                  NaN
#
#     base_split
# 0        train
# 1        train
# 2        train
# 3        train
# 4        train
# ..         ...
# 994      train
# 995      train
# 996      train
# 997      train
# 998      train
#
# [999 rows x 33 columns]

# %%
df = pd.concat([trial,train], axis=0)
for col in df.columns:
    if col not in ["filename", "start", "end", "text_lang", "text", "label_bin", "label_multi", "base_split"]:
        df[col] = df[col].apply(lambda x: x if isinstance(x, list) else [])
df
# Out:
#                             filename  start   end text_lang  \
# 0     pl_abortion_11_04_2024_n01.txt      0   266        PL
# 1     pl_abortion_11_04_2024_n01.txt    268   371        PL
# 2     pl_abortion_11_04_2024_n01.txt    373   911        PL
# 3     pl_abortion_11_04_2024_n01.txt    913  1030        PL
# 4     pl_abortion_11_04_2024_n01.txt   1032  1828        PL
# ..                               ...    ...   ...       ...
# 994  SI_interpelation_interior_7.txt      0   274        SI
# 995  SI_interpelation_interior_7.txt    276   837        SI
# 996  SI_interpelation_interior_7.txt    839  2596        SI
# 997  SI_interpelation_interior_7.txt   2598  5288        SI
# 998  SI_interpelation_interior_7.txt   5290  9806        SI
#
#                                                   text  label_bin  \
# 0    Wicemarszałek Włodzimierz Czarzasty:\nWznawiam...      False
# 1    Panowie, halo, szanujmy wszystkich gości.\nDzi...      False
# 2    Przystępujemy do rozpatrzenia punktów 10.,\n11...      False
# 3    Bardzo proszę panią poseł Annę Marię Żukowską\...      False
# 4    Panie Marszałku! Wysoka Izbo! Dlaczego kobiety...       True
# ..                                                 ...        ...
# 994  Zanimivo ob tem dejstvu je, da se pa na jugovz...       True
# 995  Prav tako poročila obeh policijskih postaj gov...       True
# 996  Naslednji primer: žena pomočnika generalnega d...       True
# 997  Policisti prav tako dobijo navodila, naj ne sp...       True
# 998  In dodatki za nadomeščanje vodje. Netransparen...       True
#
#                                            label_multi base_split  \
# 0                                                   []      trial
# 1                                                   []      trial
# 2                                                   []      trial
# 3                                                   []      trial
# 4    [Conversation_Killer, Appeal_to_Pity, Appeal_t...      trial
# ..                                                 ...        ...
# 994  [Causal_Oversimplification, Appeal_to_Fear-Pre...      train
# 995             [Appeal_to_Values, Red_Herring, Doubt]      train
# 996  [Causal_Oversimplification, Exaggeration-Minim...      train
# 997  [Consequential_Oversimplification, Exaggeratio...      train
# 998  [False_Equivalence, Exaggeration-Minimisation,...      train
#
#                             Questioning_the_Reputation  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 994                                                 []
# 995                                                 []
# 996  [mora po navodilu pomočnika generalnega direkt...
# 997  [Taka navodila policistom seveda preprečujejo ...
# 998  [Posel dobi podjetje iz hobotnice slovenskih m...
#
#         Name_Calling-Labeling  ... Obfuscation-Vagueness-Confusion Straw_Man  \
# 0                          []  ...                              []        []
# 1                          []  ...                              []        []
# 2                          []  ...                              []        []
# 3                          []  ...                              []        []
# 4                          []  ...                              []        []
# ..                        ...  ...                             ...       ...
# 994                        []  ...                              []        []
# 995                        []  ...                              []        []
# 996              [golobistov]  ...            [prisilnih sredstev]        []
# 997                        []  ...                              []        []
# 998  [golobistov, golobistov]  ...         [po mnenju poznavalcev]        []
#
#     Slogans                           Appeal_to_Fear-Prejudice  \
# 0        []                                                 []
# 1        []                                                 []
# 2        []                                                 []
# 3        []                                                 []
# 4        []                                                 []
# ..      ...                                                ...
# 994      []         [problematike kot so Romi in pa migracije]
# 995      []                                                 []
# 996      []  [zato se prične znatno povečevati število ileg...
# 997      []  [V času bivanja v Sloveniji, se nekateri ilega...
# 998      []                                                 []
#
#                              Causal_Oversimplification  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 994  [za rešitev te problematike, torej povečanega ...
# 995                                                 []
# 996  [S tem se ilegalnim migrantom sporoči, da je p...
# 997                                                 []
# 998                                                 []
#
#          Appeal_to_Authority False_Dilemma-No_Choice Whataboutism  \
# 0                         []                      []           []
# 1                         []                      []           []
# 2                         []                      []           []
# 3                         []                      []           []
# 4                         []                      []           []
# ..                       ...                     ...          ...
# 994                       []                      []           []
# 995                       []                      []           []
# 996                       []                      []           []
# 997  [tožilka Mateja Gončin]                      []           []
# 998  [po mnenju poznavalcev]                      []           []
#
#                                      False_Equivalence Guilt_by_Association
# 0                                                   []                   []
# 1                                                   []                   []
# 2                                                   []                   []
# 3                                                   []                   []
# 4                                                   []                   []
# ..                                                 ...                  ...
# 994                                                 []                   []
# 995                                                 []                   []
# 996                                                 []                   []
# 997                                                 []                   []
# 998  [Če primerjamo torej ceno mobilne hiške, ki jo...                   []
#
# [1128 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# Set random seed for reproducibility
np.random.seed(42)

# Default alt_split is same as base_split
df['alt_split'] = df['base_split']

# Select only the 'train' rows
train_rows = df[df['base_split'] == 'train']

# Stratified split: 70% stay as 'train', 30% go to 'dev'
train_idx, dev_idx = train_test_split(
    train_rows.index,
    test_size=0.3,
    stratify=train_rows['text_lang'],
    random_state=42
)

# Assign alt_split values
df.loc[train_idx, 'alt_split'] = 'train'
df.loc[dev_idx, 'alt_split'] = 'dev'

# Move all 'trial' rows to 'dev'
df.loc[df['base_split'] == 'trial', 'alt_split'] = 'dev'

# %%
# Step 1: Explode the list of labels
df_exploded = df.explode('label_multi')

# Step 2: Group by base_split and label, then count
label_counts = df_exploded.groupby(['label_multi', 'alt_split']).size().unstack(fill_value=0)
label_counts
# Out:
# alt_split                         dev  train
# label_multi
# Appeal_to_Authority                12     52
# Appeal_to_Fear-Prejudice           34     67
# Appeal_to_Hypocrisy                23     53
# Appeal_to_Pity                     20     29
# Appeal_to_Popularity               28     36
# Appeal_to_Time                     11     18
# Appeal_to_Values                   60     84
# Causal_Oversimplification          19     42
# Consequential_Oversimplification   13     30
# Conversation_Killer                28     44
# Doubt                              42    105
# Exaggeration-Minimisation          30     71
# False_Dilemma-No_Choice            10     23
# False_Equivalence                   9     10
# Flag_Waving                        16     29
# Guilt_by_Association               10     15
# Loaded_Language                    70    114
# Name_Calling-Labeling              30     78
# Obfuscation-Vagueness-Confusion    11     28
# Questioning_the_Reputation         43    103
# Red_Herring                        22     29
# Repetition                         37     69
# Slogans                             9     22
# Straw_Man                          12     19
# Whataboutism                       11     19

# %%
df.groupby(["base_split", "alt_split"]).agg('count')
# Out:
#                       filename  start  end  text_lang  text  label_bin  \
# base_split alt_split
# train      dev             300    300  300        300   300        300
#            train           699    699  699        699   699        699
# trial      dev             129    129  129        129   129        129
#
#                       label_multi  Questioning_the_Reputation  \
# base_split alt_split
# train      dev                300                         300
#            train              699                         699
# trial      dev                129                         129
#
#                       Name_Calling-Labeling  Appeal_to_Hypocrisy  ...  \
# base_split alt_split                                              ...
# train      dev                          300                  300  ...
#            train                        699                  699  ...
# trial      dev                          129                  129  ...
#
#                       Obfuscation-Vagueness-Confusion  Straw_Man  Slogans  \
# base_split alt_split
# train      dev                                    300        300      300
#            train                                  699        699      699
# trial      dev                                    129        129      129
#
#                       Appeal_to_Fear-Prejudice  Causal_Oversimplification  \
# base_split alt_split
# train      dev                             300                        300
#            train                           699                        699
# trial      dev                             129                        129
#
#                       Appeal_to_Authority  False_Dilemma-No_Choice  \
# base_split alt_split
# train      dev                        300                      300
#            train                      699                      699
# trial      dev                        129                      129
#
#                       Whataboutism  False_Equivalence  Guilt_by_Association
# base_split alt_split
# train      dev                 300                300                   300
#            train               699                699                   699
# trial      dev                 129                129                   129
#
# [3 rows x 32 columns]

# %% [markdown]
# # batching

# %%
from pathlib import Path

batch_size = 10
output_base = PROJECT_ROOT / "data/preprocessed/persuasion"
output_base.mkdir(parents=True, exist_ok=True)

for split in df["alt_split"].unique():
    for lang in df["text_lang"].unique():
        # Filter by both split and lang
        df_lang_split = df[(df["alt_split"] == split) & (df["text_lang"] == lang)] \
            .sample(frac=1, random_state=42) \
            .reset_index(drop=True)
        if df_lang_split.empty:
            continue  # Skip if no data for this combo

        # Create output directory
        lang_dir = output_base / f"{split}" / lang.lower()
        lang_dir.mkdir(parents=True, exist_ok=True)

        # Save in batches
        for i in range(0, len(df_lang_split), batch_size):
            batch_df = df_lang_split.iloc[i : i + batch_size]
            batch_index = i // batch_size
            batch_filename = f"{split}-{lang.lower()}-part_{batch_index:04d}.parquet"
            batch_path = lang_dir / batch_filename
            batch_df.to_parquet(batch_path, index=False)
            print(f"Saved {batch_path}")
# Out:
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0007.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0008.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0009.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0010.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/pl/dev-pl-part_0011.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0007.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/ru/dev-ru-part_0008.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0007.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0008.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0009.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0010.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0011.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0012.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0013.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0014.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0015.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0016.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0017.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/bg/dev-bg-part_0018.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/si/dev-si-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/si/dev-si-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/si/dev-si-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/si/dev-si-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/dev/si/dev-si-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0007.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0008.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0009.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0010.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0011.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0012.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0013.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0014.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0015.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0016.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0017.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0018.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0019.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/pl/train-pl-part_0020.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0007.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0008.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0009.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0010.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0011.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0012.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0013.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0014.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0015.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/ru/train-ru-part_0016.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0007.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0008.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0009.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0010.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0011.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0012.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0013.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0014.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0015.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0016.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0017.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0018.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0019.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0020.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0021.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0022.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0023.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0024.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/bg/train-bg-part_0025.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0000.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0001.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0002.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0003.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0004.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0005.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0006.parquet
# Saved /Users/marcinsawinski/Documents/GitHub/factue-task2/data/preprocessed/persuasion/train/si/train-si-part_0007.parquet
