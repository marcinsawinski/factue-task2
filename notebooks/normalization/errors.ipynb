# %%
# %load_ext autoreload
# %autoreload 2

# wd = '/mnt/openfact/users/msawinski/factue-task2'
wd = '/Users/marcinsawinski/Documents/GitHub/factue-task2'
import sys, os
os.chdir(wd)

# %%
import pickle
err_file = 'fallback/llm_output/normalization/define/LLAMA_31_8B/v001/default/dev/dev-eng/dev-eng_part_0000.pkl'
with open(err_file, "rb") as f:
    df = pickle.load(f)

# %%
path = '/Users/marcinsawinski/Documents/GitHub/factue-task2/fallback/llm_output/persuasion/detect/GPT_41_MINI/v001/Name_Calling-Labeling/test/pl/test-pl-part_0053.parquet'

# %%
df
# Out:
#                                                   claim_candidate  \
# original_index
# 0               [A Sikh man with no mustache is present at the...
# 1               [Challenging people to wear face coverings may...
# 2               [The Bharatiya Janata Party (BJP) government w...
# 3               [Tripti Desai converted to Christianity three ...
# 4               [Robert Mugabe's casket has been computerized ...
# 5               [Government data demonstrates that COVID shots...
# 6               [Changes to legislation have come into effect ...
# 7               [London Mayor suggests creating harmony throug...
# 8               [The author worries that Queensland is next to...
# 9               [The medical industry gives nothing away for f...
#
#                                                    claim_improved  \
# original_index
# 0               [A Sikh with no mustache appeared at the Delhi...
# 1               [Challenging people to wear face coverings may...
# 2               [Will the Bharatiya Janata Party (BJP) governm...
# 3               [Tripti Desai converted to Christianity three ...
# 4               [Robert Mugabe's casket has been computerized ...
# 5               [COVID-19 vaccines kill more people than they ...
# 6               [Changes to legislation were updated on the go...
# 7               [London Mayor recommends studying Arabic to fo...
# 8               [Lockdowns in NSW and VIC have no basis in sci...
# 9               [The medical industry gives nothing away for f...
#
#                                                              text  \
# original_index
# 0               Sikh with no mustache in Delhi farmers protest...
# 1               The government advice is not to challenge peop...
# 2                      Will our BJP\ngovernment return in 2024!!!
# 3               Ok truth out #TriptiDesai converted to christi...
# 4               MUGABE'S CASEKET\n17billion worth of Robert Mu...
# 5               Steve Kirsch, the Executive Director of the CO...
# 6               Just to let you know that the first thing that...
# 7               The London Mayor says we should create harmony...
# 8               This is the stark and very sad state of Austra...
# 9               The medical industry literally gives nothing a...
#
#                                                         reference split  \
# original_index
# 0               'Sardar with no mustache' involved in farmers ...   dev
# 1               The government advice is not to challenge some...   dev
# 2                          Will our BJP government return in 2024   dev
# 3                          Trupti Desai Converted To Christianity   dev
# 4                                  Mugabe has computerised coffin   dev
# 5               Covid-19 vaccines kill more people then they save   dev
# 6               The Control of Diseases Act in the UK changed ...   dev
# 7               Mayor of London Sadiq Khan said people should ...   dev
# 8               Jail inmate requests sentence extension due to...   dev
# 9               Flu shot is free and should be regarded as sus...   dev
#
#                    lang  init_part_no  original_index output_id prompt_name  \
# original_index
# 0               dev-eng            43               0               default
# 1               dev-eng            31               1               default
# 2               dev-eng            34               2               default
# 3               dev-eng            26               3               default
# 4               dev-eng            13               4               default
# 5               dev-eng            12               5               default
# 6               dev-eng            31               6               default
# 7               dev-eng            40               7               default
# 8               dev-eng            12               8               default
# 9               dev-eng            15               9               default
#
#                 ...              status  \
# original_index  ...
# 0               ...     [no validation]
# 1               ...     [no validation]
# 2               ...     [no validation]
# 3               ...     [no validation]
# 4               ...     [no validation]
# 5               ...     [no validation]
# 6               ...     [no validation]
# 7               ...     [no validation]
# 8               ...     [no validation]
# 9               ...  [single_candidate]
#
#                                                     plain_content  \
# original_index
# 0               [A Sikh appeared at the Delhi farmers protest ...
# 1               [Challenging people to wear face coverings may...
# 2                     [The BJP government will return in 2024!!!]
# 3               [Tripti Desai converted to Christianity three ...
# 4               [Robert Mugabe's casket, worth 17 billion, has...
# 5               [COVID-19 vaccines kill more people than they ...
# 6               [Changes to legislation were updated on the go...
# 7               [London Mayor suggests creating harmony throug...
# 8               [Lockdowns in NSW and VIC have no basis in sci...
# 9               [The medical industry gives nothing away for f...
#
#                                                             claim  error  \
# original_index
# 0               A Sikh appeared at the Delhi farmers protest w...   None
# 1               Challenging people to wear face coverings may ...   None
# 2                       The BJP government will return in 2024!!!   None
# 3               Tripti Desai converted to Christianity three y...   None
# 4               Robert Mugabe's casket, worth 17 billion, has ...   None
# 5               COVID-19 vaccines kill more people than they s...   None
# 6               Changes to legislation were updated on the gov...   None
# 7               London Mayor suggests creating harmony through...   None
# 8               Lockdowns in NSW and VIC have no basis in scie...   None
# 9               The medical industry gives nothing away for fr...   None
#
#                                                               raw  \
# original_index
# 0               [- Use only information from the post (minimal...
# 1               [- Use only information from the post (minimal...
# 2               [- Remove excessive punctuation marks (e.g., m...
# 3               [- Use only information from the post (minimal...
# 4               [Use only information from the post (minimal c...
# 5               [1. Use only information from the post (minima...
# 6               [- Use only information from the post (minimal...
# 7               [- Use only information from the post (minimal...
# 8               [Use only information from the post (minimal c...
# 9               [Use only information from the post (minimal c...
#
#                                                   definition_base  \
# original_index
# 0               [- Use only information from the post (minimal...
# 1               [- Use only information from the post (minimal...
# 2               [- Use only information from the post (minimal...
# 3               [- Use only information from the post (minimal...
# 4               [- Use only information from the post (minimal...
# 5               [- Use only information from the post (minimal...
# 6               [- Use only information from the post (minimal...
# 7               [- Use only information from the post (minimal...
# 8               [- Use only information from the post (minimal...
# 9               [- Use only information from the post (minimal...
#
#                think_content  \
# original_index
# 0                     [None]
# 1                     [None]
# 2                     [None]
# 3                     [None]
# 4                     [None]
# 5                     [None]
# 6                     [None]
# 7                     [None]
# 8                     [None]
# 9                     [None]
#
#                                                     plain_content  \
# original_index
# 0               [- Use only information from the post (minimal...
# 1               [- Use only information from the post (minimal...
# 2               [- Remove excessive punctuation marks (e.g., m...
# 3               [- Use only information from the post (minimal...
# 4               [Use only information from the post (minimal c...
# 5               [1. Use only information from the post (minima...
# 6               [- Use only information from the post (minimal...
# 7               [- Use only information from the post (minimal...
# 8               [Use only information from the post (minimal c...
# 9               [Use only information from the post (minimal c...
#
#                          status is_valid
# original_index
# 0               [no validation]   [True]
# 1               [no validation]   [True]
# 2               [no validation]   [True]
# 3               [no validation]   [True]
# 4               [no validation]   [True]
# 5               [no validation]   [True]
# 6               [no validation]   [True]
# 7               [no validation]   [True]
# 8               [no validation]   [True]
# 9               [no validation]   [True]
#
# [10 rows x 31 columns]

# %%
cols = ['error']
df.drop(columns= cols).to_parquet(path)

# %%
df['error']=df['error'].astype(str)

# %%
df.to_parquet(path)

# %%
df
# Out:
#                          filename  start   end text_lang  \
# 0  pl_abortion_11_04_2024_n13.txt    108   457        PL
# 1  pl_abortion_11_04_2024_n13.txt    459   820        PL
# 2  pl_abortion_11_04_2024_n13.txt    822  1353        PL
# 3  pl_abortion_11_04_2024_n13.txt   1355  1418        PL
# 4  pl_abortion_11_04_2024_n13.txt   1420  1639        PL
# 5  pl_abortion_11_04_2024_n13.txt   1641  1737        PL
# 6  pl_abortion_11_04_2024_n13.txt   1739  2264        PL
# 7  pl_abortion_11_04_2024_n13.txt   2266  2462        PL
# 8  pl_abortion_11_04_2024_n13.txt   2464  2973        PL
# 9  pl_abortion_11_04_2024_n13.txt   2975  3134        PL
#
#                                                 text base_split alt_split  \
# 0  Poseł Katarzyna Kierzek-Koperska:\nSzanowna Pa...       test      test
# 1  I nie mieszajmy do tego religii, bo jesteśmy t...       test      test
# 2  Skoro zatem kobiety chcą wyboru, to mamy obowi...       test      test
# 3  Wicemarszałek Monika Wielichowska:\nDziękuję b...       test      test
# 4  Poseł Katarzyna Kierzek-Koperska:\nPani marsza...       test      test
# 5  Wicemarszałek Monika Wielichowska:\nZapraszam ...       test      test
# 6  Poseł Daria Gosek-Popiołek:\nPani Marszałek! W...       test      test
# 7  Wicemarszałek Monika Wielichowska:\nDziękuję.\...       test      test
# 8  Poseł Tadeusz Woźniak:\nPani Marszałek! Wysoki...       test      test
# 9  Bo gdybyście zrealizowały swój projekt w 100%,...       test      test
#
#                                 output_id            prompt_name  \
# 0  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 1  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 2  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 3  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 4  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 5  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 6  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 7  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 8  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
# 9  GPT_41_MINI/v001/Name_Calling-Labeling  Name_Calling-Labeling
#
#   prompt_version  ...           status extra_properties  \
# 0           v001  ...           [None]           [None]
# 1           v001  ...           [None]           [None]
# 2           v001  ...           [None]           [None]
# 3           v001  ...           [None]           [None]
# 4           v001  ...           [None]           [None]
# 5           v001  ...           [None]           [None]
# 6           v001  ...           [None]           [None]
# 7           v001  ...           [None]           [None]
# 8           v001  ...  [no validation]           [None]
# 9           v001  ...  [no validation]           [None]
#
#                                          description  verdict  \
# 0  [Technique used: No — The text does not contai...      [0]
# 1  [Technique used: No — The text does not contai...      [0]
# 2  [Technique used: No — The text does not employ...      [0]
# 3  [Technique used: No — There are no loaded labe...      [0]
# 4  [Technique used: No — The text does not contai...      [0]
# 5  [Technique used: No — The text does not contai...      [0]
# 6  [Technique used: No — The text does not contai...      [0]
# 7  [Technique used: No — The text does not contai...      [0]
# 8                                             [None]     [-1]
# 9                                             [None]     [-1]
#
#                                                  raw  \
# 0  [{"description": "Technique used: No — The tex...
# 1  [{"description": "Technique used: No — The tex...
# 2  [{"description": "Technique used: No — The tex...
# 3  [{"description": "Technique used: No — There a...
# 4  [{"description": "Technique used: No — The tex...
# 5  [{"description": "Technique used: No — The tex...
# 6  [{"description": "Technique used: No — The tex...
# 7  [{"description": "Technique used: No — The tex...
# 8                                             [None]
# 9                                             [None]
#
#                                                error is_valid think_content  \
# 0                                             [None]   [True]        [None]
# 1                                             [None]   [True]        [None]
# 2                                             [None]   [True]        [None]
# 3                                             [None]   [True]        [None]
# 4                                             [None]   [True]        [None]
# 5                                             [None]   [True]        [None]
# 6                                             [None]   [True]        [None]
# 7                                             [None]   [True]        [None]
# 8            ['Unhandled exception during LLM call']   [True]        [None]
# 9  [{'message': "The response was filtered due to...   [True]        [None]
#
#   illegal_value pred
# 0        [None]    0
# 1        [None]    0
# 2        [None]    0
# 3        [None]    0
# 4        [None]    0
# 5        [None]    0
# 6        [None]    0
# 7        [None]    0
# 8        [None]   -1
# 9        [None]   -1
#
# [10 rows x 28 columns]

# %%
t ='{\n  "explanation": "The Appeal to Hypocrisy technique is used in the input text by highlighting the inconsistency of conservative politicians and Catholic clergy who, while advocating for strict abortion laws, are described as having \'czyste sumienia\' (clean consciences). This implies that they are hypocritical for imposing restrictions on women\'s rights while not considering their opinions, thus attacking their reputation by pointing out this hypocrisy.",\n  "updated_definition": null\n}'

# t ='{\n  "explanation": "The Appeal to Hypocrisy technique is used in the input text by highlighting the inconsistency of conservative politicians and Catholic clergy who, while advocating for strict abortion laws, are described as having \'czyste sumienia\' (clean consciences). This implies that they are hypocritical for imposing restrictions on women\'s rights while not considering their opinions, thus attacking their reputation by pointing out this hypocrisy.",\n  "updated_definition": ok\n}'

# %%
from factue.utils.parsers import validate_response, extract_json_from_payload
from factue.methods.llm_calls import load_template_parts

# %%
a,b = load_template_parts('persuasion', 'explain','Name_Calling-Labeling','v001')
schema = a['schema']
schema

# %%
a,b,c = extract_json_from_payload(t)
a

# %%
from jsonschema import ValidationError, validate

# %%
j = validate_response(t,schema)
j

# %%
validate(j,schema)
